# %% [markdown]
# <a href="https://colab.research.google.com/github/valentintesta/Python_DataAnalytics1/blob/main/Web_Scrapping_Python1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importar Librerias
import pandas as pd
import requests
# !pip install alphacast
from alphacast import Alphacast

# %%
#Data Freme
#Creamos el dataframe a partir del archivo csv
df = pd.read_csv("/precios-de-gas-natural-.csv")
df.head()
# Out:
#    id_pub  anio  mes                    cuenca       contrato  \
# 0       1  2019    1        Austral Santa Cruz          FIRME
# 1       2  2019    1        Austral Santa Cruz  INTERRUMPIBLE
# 2       3  2019    1        Austral Santa Cruz          TOTAL
# 3       4  2019    1  Austral Tierra del Fuego          FIRME
# 4       5  2019    1  Austral Tierra del Fuego  INTERRUMPIBLE
#
#    precio_distribuidora  precio_gnc  precio_usina  precio_industria  \
# 0                  3.56        3.43          3.10              3.27
# 1                  3.04        3.54          2.29              2.38
# 2                  3.40        3.44          2.65              3.13
# 3                  3.66        3.33          3.30              3.39
# 4                  3.43        0.00          2.33              2.28
#
#    precio_otros  precio_ppp  precio_expo indice_tiempo
# 0          3.75        3.30         2.00       2019-01
# 1          0.00        2.39         3.25       2019-01
# ...

# %%
#Borramos las filas y columnas completamente vacias
df.dropna(how= "all" , axis = 1 )
df.dropna(how= "all" , axis = 0 )
# Out:
#      id_pub  anio  mes                    cuenca       contrato  \
# 0         1  2019    1        Austral Santa Cruz          FIRME
# 1         2  2019    1        Austral Santa Cruz  INTERRUMPIBLE
# 2         3  2019    1        Austral Santa Cruz          TOTAL
# 3         4  2019    1  Austral Tierra del Fuego          FIRME
# 4         5  2019    1  Austral Tierra del Fuego  INTERRUMPIBLE
# ..      ...   ...  ...                       ...            ...
# 967     968  2023    6                  Noroeste  INTERRUMPIBLE
# 968     969  2023    6                  Noroeste          TOTAL
# 969     970  2023    6              Total Cuenca          FIRME
# 970     971  2023    6              Total Cuenca  INTERRUMPIBLE
# 971     972  2023    6              Total Cuenca          TOTAL
#
#      precio_distribuidora  precio_gnc  precio_usina  precio_industria  \
# 0                    3.56        3.43          3.10              3.27
# ...

# %%
#Ahora nos quedamos con los datos de cuenca, Austral Tierra del Fuego
df = df[df["cuenca"]== "Austral Tierra del Fuego"]
df.head()
# Out:
#     id_pub  anio  mes                    cuenca       contrato  \
# 3        4  2019    1  Austral Tierra del Fuego          FIRME
# 4        5  2019    1  Austral Tierra del Fuego  INTERRUMPIBLE
# 5        6  2019    1  Austral Tierra del Fuego          TOTAL
# 21      22  2019    2  Austral Tierra del Fuego          FIRME
# 22      23  2019    2  Austral Tierra del Fuego  INTERRUMPIBLE
#
#     precio_distribuidora  precio_gnc  precio_usina  precio_industria  \
# 3                   3.66        3.33          3.30              3.39
# 4                   3.43        0.00          2.33              2.28
# 5                   3.66        3.33          2.81              3.36
# 21                  3.65        3.19          3.00              3.50
# 22                  3.52        0.00          2.15              2.52
#
#     precio_otros  precio_ppp  precio_expo indice_tiempo
# 3            0.0        3.45         0.00       2019-01
# 4            0.0        2.37         3.49       2019-01
# ...

# %%
#Ahora nos quedamos con los datos de cuenca, Austral Tierra del Fuego
df = df[df["cuenca"]== "Austral Tierra del Fuego"]
df.head()
# Out:
#     id_pub  anio  mes                    cuenca       contrato  \
# 3        4  2019    1  Austral Tierra del Fuego          FIRME
# 4        5  2019    1  Austral Tierra del Fuego  INTERRUMPIBLE
# 5        6  2019    1  Austral Tierra del Fuego          TOTAL
# 21      22  2019    2  Austral Tierra del Fuego          FIRME
# 22      23  2019    2  Austral Tierra del Fuego  INTERRUMPIBLE
#
#     precio_distribuidora  precio_gnc  precio_usina  precio_industria  \
# 3                   3.66        3.33          3.30              3.39
# 4                   3.43        0.00          2.33              2.28
# 5                   3.66        3.33          2.81              3.36
# 21                  3.65        3.19          3.00              3.50
# 22                  3.52        0.00          2.15              2.52
#
#     precio_otros  precio_ppp  precio_expo indice_tiempo
# 3            0.0        3.45         0.00       2019-01
# 4            0.0        2.37         3.49       2019-01
# ...

# %%
#Creamos una nueva columna llamada country que luego sera declarada como entity
df["country"] = "Argentina"

# %%
#Creamos la columna Date que la usamos como index
df["Date"] = pd.to_datetime(df["indice_tiempo"], format = "%Y-%m")
df.set_index("Date", inplace= True)
df
# Out:
#             id_pub  anio  mes                    cuenca       contrato  \
# Date
# 2019-01-01       4  2019    1  Austral Tierra del Fuego          FIRME
# 2019-01-01       5  2019    1  Austral Tierra del Fuego  INTERRUMPIBLE
# 2019-01-01       6  2019    1  Austral Tierra del Fuego          TOTAL
# 2019-02-01      22  2019    2  Austral Tierra del Fuego          FIRME
# 2019-02-01      23  2019    2  Austral Tierra del Fuego  INTERRUMPIBLE
# ...            ...   ...  ...                       ...            ...
# 2023-05-01     941  2023    5  Austral Tierra del Fuego  INTERRUMPIBLE
# 2023-05-01     942  2023    5  Austral Tierra del Fuego          TOTAL
# 2023-06-01     958  2023    6  Austral Tierra del Fuego          FIRME
# 2023-06-01     959  2023    6  Austral Tierra del Fuego  INTERRUMPIBLE
# 2023-06-01     960  2023    6  Austral Tierra del Fuego          TOTAL
#
#             precio_distribuidora  precio_gnc  precio_usina  precio_industria  \
# Date
# ...
